# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\Covidset.csv")

# %%
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\Covidset.csv")

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  01/07/2020    1      7  2020    279      13             Afghanistan    AF
# 1  30/06/2020   30      6  2020    271      12             Afghanistan    AF
# 2  29/06/2020   29      6  2020    351      18             Afghanistan    AF
# 3  28/06/2020   28      6  2020    165      20             Afghanistan    AF
# 4  27/06/2020   27      6  2020    276       8             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia

# %%
df.describe()
# Out:
#                 day         month          year         cases        deaths  \
# count  26982.000000  26982.000000  26982.000000  26982.000000  26982.000000
# mean      16.197873      4.230376   2019.997517    387.160070     18.939923
# std        8.863097      1.570667      0.049770   2209.252863    121.212907
# min        1.000000      1.000000   2019.000000  -2461.000000  -1918.000000
# 25%        9.000000      3.000000   2020.000000      0.000000      0.000000
# 50%       17.000000      4.000000   2020.000000      4.000000      0.000000
# 75%       24.000000      5.000000   2020.000000     69.000000      1.000000
# max       31.000000     12.000000   2020.000000  54771.000000   4928.000000
#
#         popData2019
# count  2.691800e+04
# mean   4.673026e+07
# std    1.671715e+08
# min    8.150000e+02
# 25%    1.919968e+06
# 50%    8.776119e+06
# 75%    3.182530e+07
# max    1.433784e+09

# %%
df = df.drop(columns=["popData2019"])

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  01/07/2020    1      7  2020    279      13             Afghanistan    AF
# 1  30/06/2020   30      6  2020    271      12             Afghanistan    AF
# 2  29/06/2020   29      6  2020    351      18             Afghanistan    AF
# 3  28/06/2020   28      6  2020    165      20             Afghanistan    AF
# 4  27/06/2020   27      6  2020    276       8             Afghanistan    AF
#
#   countryterritoryCode continentExp
# 0                  AFG         Asia
# 1                  AFG         Asia
# 2                  AFG         Asia
# 3                  AFG         Asia
# 4                  AFG         Asia

# %%
df = df.drop(columns=["countryterritoryCode"])

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  01/07/2020    1      7  2020    279      13             Afghanistan    AF
# 1  30/06/2020   30      6  2020    271      12             Afghanistan    AF
# 2  29/06/2020   29      6  2020    351      18             Afghanistan    AF
# 3  28/06/2020   28      6  2020    165      20             Afghanistan    AF
# 4  27/06/2020   27      6  2020    276       8             Afghanistan    AF
#
#   continentExp
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia

# %%
df.to_csv("df_clean data.csv", index=False)
