# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
np.__version__
# Out:
# '2.3.5'

# %%
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\bitcoin_price.csv")

# %%
## To group into numerical & Categorical

cat_col = [col for col in df.columns if df[col].dtype == "object"]
num_col = [col for col in df.columns if df[col].dtype != "object"]

print("Categorial Columns", cat_col)
print("Numerical Columns", num_col)
# Out:
# Categorial Columns ['Date', 'Volume', 'Market Cap']
# Numerical Columns ['Open', 'High', 'Low', 'Close']

# %%
df[cat_col].nunique()
# Out:
# Date          1655
# Volume        1413
# Market Cap    1651
# dtype: int64

# %%
df[num_col].nunique()
# Out:
# Open     1628
# High     1626
# Low      1638
# Close    1628
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
### To drop columns

dropcategoral_columns = df.drop(columns= ["Date", "Volume", "Market Cap"])

dropcategoral_columns
# Out:
#          Open     High      Low    Close
# 0     7023.10  7253.32  7023.10  7144.38
# 1     7403.22  7445.77  7007.31  7022.76
# 2     7404.52  7617.48  7333.19  7407.41
# 3     7164.48  7492.86  7031.28  7379.95
# 4     7087.53  7461.29  7002.94  7207.76
# ...       ...      ...      ...      ...
# 1650   116.38   125.60    92.28   105.21
# 1651   139.00   139.89   107.72   116.99
# 1652   144.00   146.93   134.05   139.00
# 1653   134.44   147.49   134.00   144.54
# 1654   135.30   135.98   132.10   134.21
#
# [1655 rows x 4 columns]
