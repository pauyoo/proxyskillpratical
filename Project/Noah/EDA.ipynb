# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.preprocessing import MinMaxScaler, StandardScaler
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\bitcoin_price.csv")

# %%
sns.boxplot(x='Market Cap', data = df);
## Boxplot for outliers detection

# %%
num_cols = df.select_dtypes(include='number').columns
cat_cols = df.select_dtypes(exclude='number').columns

# %%
num_cols
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
cat_cols
# Out:
# Index(['Date', 'Volume', 'Market Cap'], dtype='object')

# %%
df.hist(figsize=(10, 8), bins=20)  ## Univariate Analysis
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(df.columns), 1, figsize=(7, 18), dpi=95)
for i, col in enumerate(df.columns):
    axs[i].boxplot(df[col], vert=False)
    axs[i].set_ylabel(col)
plt.tight_layout()
plt.show()


## This plot shows how outliers, and mean
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 fig, axs = plt.subplots(len(df.columns), 1, figsize=(7, 18), dpi=95)
#       2 for i, col in enumerate(df.columns):
# ----> 3     axs[i].boxplot(df[col], vert=False)
#       4     axs[i].set_ylabel(col)
#       5 plt.tight_layout()
#
# File c:\Users\PAUL\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
