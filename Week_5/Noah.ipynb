# %%
def name():
    print("myname is noah oooo")
name()
# Out:
# myname is noah oooo

# %%
def sum (a,b):
    return a+b
result= sum(2,3)
print(result)
# Out:
# 5

# %%
def grade(score):
    if score>=50:
        return"pass"
    else:
        return"fail"
    print(grade(50))
grade(45)
# Out:
# 'fail'

# %%
print (grade(34))
# Out:
# fail

# %%
def students(numbers):
    return sum(numbers)

print(students([1,2,3,4]))
# Out:
# 10

# %%
def average_score(scores):
    return sum(scores) / len(scores)

print(average_score([60, 70, 80]))
# Out:
# 70.0
