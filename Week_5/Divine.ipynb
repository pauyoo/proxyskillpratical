# %%
def sum(a,b):
    return a+b    
result=sum(2,3)
print(result)
# Out:
# 5

# %%
def students(numbers):
    return sum(numbers)
print(students([1,2,3,4,5]))
# Out:
# 15

# %%
def students(numbers):
    return sum(numbers)/len(numbers)
print(students([50,30,70]))
# Out:
# 50.0
