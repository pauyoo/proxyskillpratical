# %%
def name():
    print("my name is Gift")
    name()

# %%
def happy_birthday():
    print("happy birthday") 
    print("how old are you")
    print("happy birthday to you")
happy_birthday()
# Out:
# happy birthday
# how old are you
# happy birthday to you

# %%
def sum(x ,y):
    return x + y 
result = sum(2,3)

print (result)
# Out:
# 5

# %%
def grade(score):
    if score >= 50:
        return "Pass"
    else:
        return"Fail"
    
print(grade(50))
# Out:
# Pass

# %%
print(grade(34))
# Out:
# Fail

# %%
def networth(money):
    if networth >= 20000000:
        return "rich"
    else:
        return "poor"

# %%
def birthday(name,age):
    print(f"Happy birthday {name}")
    print(f"I am {age} years old")
birthday("Gift" ,14)
# Out:
# Happy birthday Gift
# I am 14 years old

# %%
def age(year):
    if age >= 11:
       return  ("year 7")
    elif age >= 12:
         return ("year 8")
    elif age >= 13:
         return ("year 9") 
    elif age >= 14:
         return("year 10")
    else:
        return("year 11")

     year=int(input("which age are you"))
     print(age(year))
# Out:
#   File <tokenize>:13
#     year=int(input("which age are you"))
#     ^
# IndentationError: unindent does not match any outer indentation level
