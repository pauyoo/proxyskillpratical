# %%
def name():
    print("My name is Nathaniel")
name()
# Out:
# My name is Nathaniel

# %%
def sum(a,b):
  return a+b
result=sum(2,3) 
print(result)
# Out:
# 5

# %%
def grade (score):
    if score>= 50
        return"Pass"
    else :
        return "Fail"
    
print (grade (50))
