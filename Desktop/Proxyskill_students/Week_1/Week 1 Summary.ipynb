# %%
##

# %% [markdown]
# Objectives
# - Printing with the f string
# - Data Types
# - Variables
# - Data Types
# - Typecasting
# - Input Function
# - Conditional Statements
#
# Exercises
# Grade scaling using conditional statements
# CGPA Calculator

# %%
## Lesson 1 Printing with the f string 
## Examples 2

class_name = "SProxyskill"
print(f"Hello {class_name}")
# Out:
# Hello SProxyskill

# %%
my_name = "Hilary"
print (my_name)
print(f"My name is {my_name} and I am a fine boy")
# Out:
# Hilary
# My name is Hilary and I am a fine boy

# %%
myname = "Hilary" 
print (myname)
mysurname= "Rex" 
print (mysurname)
print(f"My name is {myname} and {mysurname}")
# Out:
# Hilary
# Rex
# My name is Hilary and Rex

# %%
myage= 10
aboy= True
myname = "Hilary" 
print(f"i am(myage) and i am(aboy) and my name is(myname)")
# Out:
# i am(myage) and i am(aboy) and my name is(myname)

# %%
## Printing with the f string 
## Example 2

family_name = "Moses"
print(f"Hello I am Mr Emmanuel {family_name}")
# Out:
# Hello I am Mr Emmanuel Moses

# %%
## Printing with the f string 
## Example 3

my_email = "paulayodele04@gmail.com"
print(f"My email is {my_email}")
# Out:
# My email is paulayodele04@gmail.com

# %%
## Integers 
## Example 1

age = 15
print(f"You are {age} years old")
# Out:
# You are 15 years old

# %%
## Integers 
## Example 2

food = "eba"
print(f"I am eating 12 {food} this morning")
# Out:
# I am eating 12 eba this morning

# %%
## Float : A float is a number with decimal
## Example 1
cost_price = 100.50
selling_price = 120.50

print(f"This is the cost price{cost_price} from my inventry")

print(f"This is the selling price{cost_price} from my inventry")


## Class Test: Calculate the;
## Gain, percentage gain and print result out in a f string
# Out:
# This is the cost price100.5 from my inventry
# This is the selling price100.5 from my inventry

# %%
# Float
# # Example 2
CGPA = 4.33 
print(f"This is my grade {CGPA} mum")
# Out:
# This is my grade 4.33 mum

# %%
## Booleans: True or False
# Example 1

A_boy = False

print(f"Is he a boy: {A_boy}")
# Out:
# Is he a boy: False

# %%
## Booleans: True or False
# Example 2

Is_it_for_sale = True

print(f"Is the item for sale: {Is_it_for_sale}")
# Out:
# Is the item for sale: True

# %%
## Booleans with Conditioanl Statements
# Example 2

for_sale = True

if for_sale:
    print("The item is for sale")
else:
    print("The item is not for sale")
# Out:
# The item is for sale

# %%
## Booleans with Conditioanl Statements
# Example 3

Nigerian_won = True
Nigerian_won_WC = False

if Nigerian_won:
    print("We won the Semifinal")
if Nigerian_won_WC:
    print("We won the Worldcup")
else:
    print("We lost the World cup")
# Out:
# We won the Semifinal
# We lost the World cup

# %%
## Typecasting: This is converting a variable from one datatype to another
old_CGPA = 4.06

print(type(old_CGPA))
print(old_CGPA)
# Out:
# <class 'float'>
# 4.06

# %%
## After typecasting; datatype was changed to an Integer from float so the decimal gets roundedup

old_CGPA = int(old_CGPA)

print(type(old_CGPA))
print(old_CGPA)
# Out:
# <class 'int'>
# 4

# %%
## Typecasting 
## Example 1: 
age = 25
print(type(age))
print(age)
# Out:
# <class 'int'>
# 25

# %%
## To typecast
age = str(age)

print(type(age))
print(age)
# Out:
# <class 'str'>
# 25

# %%
## Cocatinating our str variable

total_age = age + age + age

total_age
# Out:
# '252525'

# %%
## Typecasting Boolean
school = "Geochin"

school = bool(school)

print(school)
# Out:
# True

# %%
## Typecasting Boolean
school = ""

school = bool(school)

print(school)
# Out:
# False
