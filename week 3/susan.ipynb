# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\pregnancy data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              233 non-null    int64
#  1   Gestational age  233 non-null    int64
#  2   weight           233 non-null    int64
#  3   BP               233 non-null    object
#  4   Pulse            230 non-null    object
#  5   Hapetis B        232 non-null    object
#  6   PCV              230 non-null    object
#  7   Urine Sugar      233 non-null    object
#  8   Oedema           233 non-null    object
#  9   Fundal Height    232 non-null    object
#  10  Presentation     232 non-null    object
#  11  Position         223 non-null    object
#  12  FHR              232 non-null    object
#  13  Genotype         225 non-null    object
#  14  Blood Group      225 non-null    object
#  15  XYZ              233 non-null    object
#  16  Malaria          233 non-null    object
# ...

# %%
df.head()
# Out:
#    Age  Gestational age  weight      BP Pulse Hapetis B     PCV Urine Sugar  \
# 0   39               36      55   97/74    87       Neg  35.00%         Neg
# 1   24               36      60   95/59    73       Neg  32.00%         Neg
# 2   32               32      91  122/70    88       Neg  32.00%         Neg
# 3   26               12      99  125/71    98       Neg  29.00%         Neg
# 4   23               16      79  117/68    90       Neg  33.00%         Neg
#
#   Oedema Fundal Height Presentation Position FHR Genotype Blood Group  XYZ  \
# 0    Nil         38/52         Ceph      Loa  HD       AA          O+  Neg
# 1    Nil         36/52         Ceph      Loa  HD      NaN          A+  Neg
# 2    Nil         29/52         Ceph      Roa  HD       AA          O+  Neg
# 3    Nil         35/52         Ceph      Loa  HD       AS         AB+  Neg
# 4    Nil         16/52        Bulky      Loa  HD       AA          O+  Neg
#
#   Malaria   RBS/FBS(mg) Occupation
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Length: 233, dtype: bool
