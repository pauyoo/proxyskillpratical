# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\PAUL\Desktop\dataset\boston_population_by_zip.csv")

# %%
df.shape
# Out:
# (534, 2)

# %%
df.head()
# Out:
#    zip_code  Population
# 0      2301       68571
# 1      2148       65386
# 2      2155       62996
# 3      2360       60793
# 4      2151       60736
