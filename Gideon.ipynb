# %%
number='4.0'
print(str(number))
new_number=number+number
print(new_number)
# Out:
# 4.0
# 4.04.0

# %%
mynumber= 9.09
newnumber = (str(mynumber))

print(mynumber)
solution = mynumber + mynumber

print(solution)
# Out:
# 9.09
# 18.18

# %%
#Gideon project 
overall_performance=int(input("input your overall performance"))
if overall_performance >=90:
    print("promoted")
if overall_performance <89 >75:
    print("promoted on trial")
if overall_performance >44 <75:
    print("advised to repeat")
if overall_performance >0 <45:
    print("repeat")

# %%
#susan 
name=int(55.8)
print(type(name))
# Out:
# <class 'int'>

# %%
#Daniel
name=int(14.6)
print(type(name))
# Out:
# <class 'int'>

# %%
def composition(name,age,hobby,complexion):
    print(f"my name is {name} ")
    print(f"I am {age} years old")
    print(f"My hobby is {hobby}")
    print(f"I am {complexion} in complexion")

composition(input("Your name: "),input("How old are you? "),input("What is your hobby? "),input("What is your complexion? "))
# Out:
# my name is gideon
# I am 15 years old
# My hobby is content creation
# I am fair in complexion
