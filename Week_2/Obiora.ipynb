# %%
#noah is three years older than obiora.Obiora is Eight years old.Therefore Noah is Eleven years old#
Obiora_age=8
Noah_age=Obiora_age+3
Sum_of_ages=Obiora_age+Noah_age
print(f"{Sum_of_ages} years old")
# Out:
# 19 years old

# %%
Num_1=int(input("input your first number"))
Num_2=int(input("enter your second number"))
Total=Num_1+Num_2
print(Total)
# Out:
# 96059601
