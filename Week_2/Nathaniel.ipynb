# %%
firstname="nathaniel"
surname="akingbade"
print(f"my name is {surname} {firstname}")
# Out:
# my name is akingbade nathaniel

# %%
l = int(input("enter your length"))
b = int(input("enter your breadth"))
area= l * b
print(area)
# Out:
# 12
