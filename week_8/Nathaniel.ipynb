# %%
def name():
    print("My name is Nathaniel")

name()
# Out:
# My name is Nathaniel

# %%
def grade(score):
    if score >= 50:
        print ("Failed course")
    else:
        print ("Passed Course")

grade(29)
# Out:
# Passed Course
