# %%
def composition(name,age,hobby):
    print(f"my name is {name} ")
    print(f"I am {age} years old")
    print(f"My hobby is {hobby}")

composition(input("Your name: "),input("How old are you? "),input("What is your hobby? "))

# %%
def account_balance(name, ammount):
    print(f"Hello {name}")
    print(f"Your account balance is {ammount}")

account_balance(input("Whats your name: "), input("Whats your account balance: " ))
# Out:
# Hello Hilary
# Your account balance is 200000
