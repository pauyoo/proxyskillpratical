# %%
mycgpa=3.04
print(type(mycgpa))
print(mycgpa)

newcpga=int(mycgpa)
print(type(newcpga))
print(f"This is the new rounded up CGPA:{newcpga}")
# Out:
# <class 'float'>
# 3.04
# <class 'int'>
# this is the new rounded up CGPA:3

# %%
# Out:
# <class 'float'>
# <class 'str'>
# 9.09
